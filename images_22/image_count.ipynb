# %%
import pandas as pd

metadata = pd.read_csv('train_crop_images.csv', 
                 na_values=['NA', 'N/A', ''],
                 keep_default_na=True,
                 quotechar='"',
                 doublequote=True,
                 engine='python')

class_counts = metadata['SURVEY_LC1'].value_counts()
print(class_counts)
# Out:
# SURVEY_LC1
# B32    528
# B14    528
# B33    528
# B11    528
# B16    528
# B12    528
# B31    528
# B55    528
# B15    528
# B13    528
# B21    528
# B22    528
# Name: count, dtype: int64
